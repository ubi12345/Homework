# %% [markdown]
# <a href="https://colab.research.google.com/github/ubi12345/Homework/blob/master/%EC%97%B4%EC%9C%A0%EC%B2%B4%EA%B3%B5%ED%95%99%EC%8B%A4%ED%97%98-2014010664-HW05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

from mpl_toolkits import mplot3d

def homework05():
  theta = 2 *np.pi*np.random.random(1000)
  r=6*np.random.random(1000)
  x=np.ravel(r*np.sin(theta))
  y=np.ravel(r*np.cos(theta))
  z=np.exp(-0.1*x**2-0.1*y**2)
  return x,y,z

x,y,z=homework05()

ax=plt.axes(projection='3d')
ax.plot_trisurf(x,y,z,cmap='viridis',edgecolor='none')
ax.set_xlim(-5,5);ax.set_ylim(-5,5);ax.set_zlim(0,1);

ax.set_xlabel('x-axis');ax.set_ylabel('y-axis');ax.set_zlabel('z-axis');
